# %%
import pandas as pd
import os
import numpy as np
import requests
import geopandas as gpd 
from shapely.geometry import Point

# %%
def distance_meters(lat_start, long_start, lat_finish, long_finish):
    # return the distance in metres between to latitude/longitude pair point in degrees (i.e.: 40.392436 / -3.6994487)
    start = to_mercator(lat_start, long_start)
    finish = to_mercator(lat_finish, long_finish)
    return start.distance(finish)

def distance_m(mercator_start, mercator_finish):
    return mercator_start.distance(mercator_finish)


def to_mercator(lat, long):
    # transform latitude/longitude data in degrees to pseudo-mercator coordinates in metres
    c = gpd.GeoSeries([Point(lat, long)], crs=4326)
    c = c.to_crs(3857)
    return c

# %%
#colegios_publicos_data = pd.read_csv("../data/colegios-publicos.csv", sep =';')
#escuelas_infantiles_data = pd.read_csv ("../data/escuelas-infantiles.csv", sep =';')
bicimad_data = pd.read_json("../data/bicimad.json")

# %%
os.listdir("../data")
# Out:
# ['.DS_Store',
#  'bicimad.json',
#  'colegios-publicos.csv',
#  'escuelas-infantiles.csv']

# %%
# Opción 2 : Extrayendo info de la API de colegios_publicos_data

colegios_publicos_data = requests.get('https://datos.madrid.es/egob/catalogo/202311-0-colegios-publicos.json')
colegios_publicos_data = colegios_publicos_data.json()

escuelas_infantiles_data = requests.get('https://datos.madrid.es/egob/catalogo/202318-0-escuelas-infantiles.json')
escuelas_infantiles_data = escuelas_infantiles_data.json()

bicimad_data = pd.read_json("../data/bicimad.json")

# %%
# Normalizamos el Json para obtener los datos de la tabla
colegios_publicos_data = pd.json_normalize(colegios_publicos_data['@graph'])

# %%
# Normalizamos el Json para obtener los datos de la tabla
escuelas_infantiles_data = pd.json_normalize(escuelas_infantiles_data['@graph'])

# %%
bicimad_data.head()
# Out:
#    id                name  light number  \
# 0   1    Puerta del Sol A      2     1a
# 1   2    Puerta del Sol B      1     1b
# 2   3         Miguel Moya      2      2
# 3   4  Plaza Conde Suchil      0      3
# 4   5            Malasaña      2      4
#
#                                     address  activate  no_available  \
# 0                       Puerta del Sol nº 1         1             0
# 1                       Puerta del Sol nº 1         1             0
# 2                    Calle Miguel Moya nº 1         1             0
# 3  Plaza del Conde del Valle de Súchil nº 3         1             0
# 4               Calle Manuela Malasaña nº 5         1             0
#
#    total_bases  dock_bikes  free_bases  reservations_count geometry_type  \
# 0           30          15          11                   0         Point
# 1           30          22           4                   0         Point
# 2           24          12          11                   0         Point
# 3           18           4          11                   0         Point
# 4           24          12          12                   0         Point
#
#                       geometry_coordinates
# 0                 [-3.7018341, 40.4172137]
# 1  [-3.701602938060457, 40.41731271011562]
# 2                 [-3.7058415, 40.4205886]
# 3                 [-3.7069171, 40.4302937]
# 4                 [-3.7025875, 40.4285524]

# %%
escuelas_infantiles_data.head()
# Out:
#                                                  @id  \
# 0  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                @type       id  \
# 0  https://datos.madrid.es/egob/kos/entidadesYorg...    58241
# 1  https://datos.madrid.es/egob/kos/entidadesYorg...  4549323
# 2  https://datos.madrid.es/egob/kos/entidadesYorg...  5299172
# 3  https://datos.madrid.es/egob/kos/entidadesYorg...  5633312
# 4  https://datos.madrid.es/egob/kos/entidadesYorg...  4724002
#
#                                        title  \
# 0      Escuela infantil municipal Agua Dulce
# 1          Escuela infantil municipal Altair
# 2        Escuela infantil municipal Amanecer
# 3  Escuela infantil municipal Ana de Austria
# 4      Escuela infantil municipal Campanilla
#
#                                             relation  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                 address.district.@id  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                     address.area.@id address.locality  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#   address.postal-code    address.street-address  location.latitude  \
# 0               28039          CALLE LEÑEROS 25          40.454061
# 1               28044  CALLE JOSE DE CADALSO 43          40.378132
# 2               28032           CALLE TITANIO 7          40.401990
# 3               28050   CALLE ANA DE AUSTRIA 32          40.495522
# 4               28020             CALLE AVILA 4          40.452700
#
#    location.longitude                     organization.organization-desc  \
# 0           -3.709371   ENSEÑANZA: Educación Infantil (Primer Ciclo) ...
# 1           -3.768701   ENSEÑANZA: Educación infantil (Primer ciclo) ...
# 2           -3.601044   ENSEÑANZA: Educación infantil (Primer Ciclo)....
# 3           -3.655737   ENSEÑANZA: Educación infantil (Primer ciclo) ...
# 4           -3.701998   ENSEÑANZA: Educación infantil (Primer Ciclo) ...
#
#   organization.accesibility organization.schedule       organization.services  \
# 0                         0                        Horario ampliado. Comedor.
# 1                         0
# 2                         0
# 3                         0                           Educación de 0 a 3 años
# 4                         0
#
#               organization.organization-name
# 0      Escuela infantil municipal Agua Dulce
# 1          Escuela infantil municipal Altair
# 2        Escuela infantil municipal Amanecer
# 3  Escuela infantil municipal Ana de Austria
# 4      Escuela infantil municipal Campanilla

# %%
colegios_publicos_data.head()
# Out:
#                                                  @id  \
# 0  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 1  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 2  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 3  https://datos.madrid.es/egob/catalogo/tipo/ent...
# 4  https://datos.madrid.es/egob/catalogo/tipo/ent...
#
#                                                @type       id  \
# 0  https://datos.madrid.es/egob/kos/entidadesYorg...   176850
# 1  https://datos.madrid.es/egob/kos/entidadesYorg...     5075
# 2  https://datos.madrid.es/egob/kos/entidadesYorg...  4693138
# 3  https://datos.madrid.es/egob/kos/entidadesYorg...     5076
# 4  https://datos.madrid.es/egob/kos/entidadesYorg...     5077
#
#                                        title  \
# 0              Colegio Público Adolfo Suárez
# 1              Colegio Público Agustina Díez
# 2  Colegio Público Agustín Rodriguez Sahagún
# 3            Colegio Público Alberto Alcocer
# 4        Colegio Público Alcalde de Móstoles
#
#                                             relation  \
# 0  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 1  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 2  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 3  http://www.madrid.es/sites/v/index.jsp?vgnextc...
# 4  http://www.madrid.es/sites/v/index.jsp?vgnextc...
#
#                                 address.district.@id  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 3  https://datos.madrid.es/egob/kos/Provincia/Mad...
# 4  https://datos.madrid.es/egob/kos/Provincia/Mad...
#
#                                     address.area.@id address.locality  \
# 0  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 1  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 2  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 3  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
# 4  https://datos.madrid.es/egob/kos/Provincia/Mad...           MADRID
#
#   address.postal-code               address.street-address  location.latitude  \
# 0               28050    CALLE INFANTA CATALINA MICAELA 31          40.488603
# 1               28038                      CALLE VESUBIO 5          40.388191
# 2               28031  CALLE LA GRANJA DE SAN ILDEFONSO 17          40.368040
# 3               28022    AVENIDA CANILLEJAS A VICALVARO 56          40.433338
# 4               28044        CALLE ALDEANUEVA DE LA VERA 9          40.379837
#
#    location.longitude                     organization.organization-desc  \
# 0           -3.652554   ENSEÑANZAS: Segundo ciclo de E. Infantil - Pr...
# 1           -3.647237   ENSEÑANZA: Educación infantil - Primaria METR...
# 2           -3.622168   ENSEÑANZA: Educacion Infantil - Primaria - En...
# 3           -3.612052   ENSEÑANZA: Educación Infantil - Primaria - En...
# 4           -3.776448   ENSEÑANZA: Educación Infantil - Primaria BUS:...
#
#   organization.accesibility organization.schedule  \
# 0                         0
# 1                         0
# 2                         0
# 3                         0
# 4                         0
#
#                                organization.services  \
# 0     Comedor - Horario ampliado - Planes de mejora.
# 1                         Comedor - Horario ampliado
# 2      Horario ampliado - Comedor - Planes de mejora
# 3  Comedor - Transporte - Horario ampliado - Plan...
# 4  Transporte - Comedor - Horario ampliado - Plan...
#
#               organization.organization-name
# 0              Colegio Público Adolfo Suárez
# 1              Colegio Público Agustina Díez
# 2  Colegio Público Agustín Rodriguez Sahagún
# 3            Colegio Público Alberto Alcocer
# 4        Colegio Público Alcalde de Móstoles

# %%
#Eliminamos columnas de Escuela infantiles:

escuelas_infantiles_data = escuelas_infantiles_data.drop(columns=["@id","@type","id","relation","address.district.@id","address.area.@id","address.locality","address.postal-code","organization.organization-desc","organization.accesibility","organization.schedule","organization.services","organization.organization-name"])
# "@id","@type","id","title","relation","address.district.@id","address.area.@id","address.locality","address.postal-code","address.street-address","location.latitude","location.longitude","organization.organization-desc","organization.accesibility","organization.schedule","organization.services","organization.organization-name"
escuelas_infantiles_data.head()
# Out:
#                                        title    address.street-address  \
# 0      Escuela infantil municipal Agua Dulce          CALLE LEÑEROS 25
# 1          Escuela infantil municipal Altair  CALLE JOSE DE CADALSO 43
# 2        Escuela infantil municipal Amanecer           CALLE TITANIO 7
# 3  Escuela infantil municipal Ana de Austria   CALLE ANA DE AUSTRIA 32
# 4      Escuela infantil municipal Campanilla             CALLE AVILA 4
#
#    location.latitude  location.longitude
# 0          40.454061           -3.709371
# 1          40.378132           -3.768701
# 2          40.401990           -3.601044
# 3          40.495522           -3.655737
# 4          40.452700           -3.701998

# %%
#Eliminamos columnas de colegios_publicos_data:

colegios_publicos_data = colegios_publicos_data.drop(columns=["@id","@type","id","relation","address.district.@id","address.area.@id","address.locality","address.postal-code","organization.organization-desc","organization.accesibility","organization.schedule","organization.services","organization.organization-name"])
#Comprobamos que no existan nulos:
colegios_publicos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   248 non-null    object
#  1   address.street-address  248 non-null    object
#  2   location.latitude       248 non-null    float64
#  3   location.longitude      248 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 7.9+ KB

# %%
colegios_publicos_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   title                   248 non-null    object
#  1   address.street-address  248 non-null    object
#  2   location.latitude       248 non-null    float64
#  3   location.longitude      248 non-null    float64
# dtypes: float64(2), object(2)
# memory usage: 7.9+ KB

# %%
# incluimos las columnas con la source en ambos dataset:
colegios_publicos_data = colegios_publicos_data.assign(Tipo_Centro = "Colegios Publicos")
escuelas_infantiles_data =escuelas_infantiles_data.assign(Tipo_Centro = "Escuelas Infantiles")
## colegios_publicos_data ["Tipo_Centro"] = "Colegios Publicos"
## escuelas_infantiles_data =["Tipo_Centro"] = "Escuelas Infantiles"

# %%
colegios_publicos_data.head()
# Out:
#                                        title  \
# 0              Colegio Público Adolfo Suárez
# 1              Colegio Público Agustina Díez
# 2  Colegio Público Agustín Rodriguez Sahagún
# 3            Colegio Público Alberto Alcocer
# 4        Colegio Público Alcalde de Móstoles
#
#                 address.street-address  location.latitude  location.longitude  \
# 0    CALLE INFANTA CATALINA MICAELA 31          40.488603           -3.652554
# 1                      CALLE VESUBIO 5          40.388191           -3.647237
# 2  CALLE LA GRANJA DE SAN ILDEFONSO 17          40.368040           -3.622168
# 3    AVENIDA CANILLEJAS A VICALVARO 56          40.433338           -3.612052
# 4        CALLE ALDEANUEVA DE LA VERA 9          40.379837           -3.776448
#
#          Tipo_Centro
# 0  Colegios Publicos
# 1  Colegios Publicos
# 2  Colegios Publicos
# 3  Colegios Publicos
# 4  Colegios Publicos

# %%
#Ahora queremos crear un solo dataset para todos los datos del ayuntamiento:
ayuntamiento_data= pd.concat([colegios_publicos_data, escuelas_infantiles_data], axis=0)
ayuntamiento_data.head()
#Comprobaciones:
#len_data = len (ayuntamiento_data)
#len_colegios = len (colegios_publicos_data)
#len_escuelas =len (escuelas_infantiles_data)
# Out:
#                                        title  \
# 0              Colegio Público Adolfo Suárez
# 1              Colegio Público Agustina Díez
# 2  Colegio Público Agustín Rodriguez Sahagún
# 3            Colegio Público Alberto Alcocer
# 4        Colegio Público Alcalde de Móstoles
#
#                 address.street-address  location.latitude  location.longitude  \
# 0    CALLE INFANTA CATALINA MICAELA 31          40.488603           -3.652554
# 1                      CALLE VESUBIO 5          40.388191           -3.647237
# 2  CALLE LA GRANJA DE SAN ILDEFONSO 17          40.368040           -3.622168
# 3    AVENIDA CANILLEJAS A VICALVARO 56          40.433338           -3.612052
# 4        CALLE ALDEANUEVA DE LA VERA 9          40.379837           -3.776448
#
#          Tipo_Centro
# 0  Colegios Publicos
# 1  Colegios Publicos
# 2  Colegios Publicos
# 3  Colegios Publicos
# 4  Colegios Publicos

# %%
#Vamos a poner los datos de las direcciones en minusculas. 

ayuntamiento_data['address.street-address']=ayuntamiento_data['address.street-address'].str.title()

ayuntamiento_data.head()
# Out:
#                                        title  \
# 0              Colegio Público Adolfo Suárez
# 1              Colegio Público Agustina Díez
# 2  Colegio Público Agustín Rodriguez Sahagún
# 3            Colegio Público Alberto Alcocer
# 4        Colegio Público Alcalde de Móstoles
#
#                 address.street-address  location.latitude  location.longitude  \
# 0    Calle Infanta Catalina Micaela 31          40.488603           -3.652554
# 1                      Calle Vesubio 5          40.388191           -3.647237
# 2  Calle La Granja De San Ildefonso 17          40.368040           -3.622168
# 3    Avenida Canillejas A Vicalvaro 56          40.433338           -3.612052
# 4        Calle Aldeanueva De La Vera 9          40.379837           -3.776448
#
#          Tipo_Centro
# 0  Colegios Publicos
# 1  Colegios Publicos
# 2  Colegios Publicos
# 3  Colegios Publicos
# 4  Colegios Publicos

# %%
## NO NECESARIO CON API ##

# Ahora vamos a sustituir los valore NaN por 
# ayuntamiento_data['location.latitude'] = ayuntamiento_data['location.latitude'].replace(np.nan,"S/N")

# %%
## NO NECESARIO CON API ##

#Ahora queremos añadir una columna con los datos de NOMBRE-VIA, CLASE-VIAL y NUM.
## ayuntamiento_data["Place_address"] = ayuntamiento_data["CLASE-VIAL"] +" "+ ayuntamiento_data['NOMBRE-VIA']  + ", "+ ayuntamiento_data["NUM"].astype(str)

# %%
# Limpiamos dataset bicimad: 
# Eliminamos las columnas ['light',"number","activate","no_available","total_bases", "dock_bikes","free_bases","reservations_count","geometry_type"

bicimad_data = bicimad_data.drop(columns=['id','light',"number","activate","no_available","total_bases", "dock_bikes","free_bases","reservations_count","geometry_type"])

# %%
## Separamos la columna geometry_coordinates

#bicimad_data = bicimad_data["geometry_coordinates"].str.split()
#bicimad_data


bicimad_data['LONGITUD']=bicimad_data['geometry_coordinates'].map(lambda x:x.split(',')[0].replace("[","")).astype(float)
bicimad_data['LATITUD']=bicimad_data['geometry_coordinates'].map(lambda x:x.split(',')[1].replace("]","")).astype(float)

# %%
#Eliminamos Geometry_coordinates

bicimad_data = bicimad_data.drop(columns=['geometry_coordinates'])
bicimad_data.head()
# Out:
#                  name                                   address  LONGITUD  \
# 0    Puerta del Sol A                       Puerta del Sol nº 1 -3.701834
# 1    Puerta del Sol B                       Puerta del Sol nº 1 -3.701603
# 2         Miguel Moya                    Calle Miguel Moya nº 1 -3.705842
# 3  Plaza Conde Suchil  Plaza del Conde del Valle de Súchil nº 3 -3.706917
# 4            Malasaña               Calle Manuela Malasaña nº 5 -3.702587
#
#      LATITUD
# 0  40.417214
# 1  40.417313
# 2  40.420589
# 3  40.430294
# 4  40.428552

# %%
bicimad_data.head()
# Out:
#                  name                                   address  LONGITUD  \
# 0    Puerta del Sol A                       Puerta del Sol nº 1 -3.701834
# 1    Puerta del Sol B                       Puerta del Sol nº 1 -3.701603
# 2         Miguel Moya                    Calle Miguel Moya nº 1 -3.705842
# 3  Plaza Conde Suchil  Plaza del Conde del Valle de Súchil nº 3 -3.706917
# 4            Malasaña               Calle Manuela Malasaña nº 5 -3.702587
#
#      LATITUD
# 0  40.417214
# 1  40.417313
# 2  40.420589
# 3  40.430294
# 4  40.428552

# %%
## Obtenemos la columna Distancia con la función mercator 

## bicimad_data
#bicimad_data (distance_a)

## ayuntamiento_data
#bicimad_data (distance_b)

# %%
## Renombramos las columnas de nuestros dataframes:

ayuntamiento_data = ayuntamiento_data.rename(columns={'location.latitude':'lat_start','location.longitude':'long_start'})
bicimad_data = bicimad_data.rename(columns={'LONGITUD':'lat_finish','LATITUD':'long_finish'})

# %%
### introducir valores en la columna distance con lambda
ayuntamiento_data["PUNTO A"] = ayuntamiento_data.apply(lambda x: to_mercator(x["lat_start"],x["long_start"]), axis = 1)

bicimad_data["PUNTO B"] = bicimad_data.apply(lambda x: to_mercator(x["lat_finish"],x["long_finish"]), axis = 1)

# %%
## Unimos los dataset

dataset = pd.merge(ayuntamiento_data,bicimad_data,how="cross")

# %%
## AÑADIMOS LA COLUMNA con el resultado de distance meters:

dataset['Distancia'] = dataset.apply(lambda x: distance_m(x["PUNTO A"], x["PUNTO B"]), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/30/vsgs8bp94b7b17m8zr60lgnh0000gn/T/ipykernel_12063/2847666941.py in <module>
#       2
#       3 dataset['Distancia'] = dataset.apply(lambda x: distance_m(x["PUNTO A"], x["PUNTO B"]), axis = 1)
# ----> 4 dataset.distancia()
#
# ~/miniconda3/envs/jupyter_env/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'distancia'

# %%
#Limpiamos las columnas que no necesitamos:

dataset = dataset.drop(['lat_start','long_start', 'long_finish', 'lat_finish' ], axis='columns')

# %%
#Limpiamos las columnas que no necesitamos:(PUNTO A)
dataset = dataset.drop(['PUNTO A','PUNTO B'], axis='columns')

# %%
dataset.head(10)
# Out:
#                            title             address.street-address  \
# 0  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 1  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 2  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 3  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 4  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 5  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 6  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 7  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 8  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
# 9  Colegio Público Adolfo Suárez  Calle Infanta Catalina Micaela 31
#
#          Tipo_Centro                 name  \
# 0  Colegios Publicos     Puerta del Sol A
# 1  Colegios Publicos     Puerta del Sol B
# 2  Colegios Publicos          Miguel Moya
# 3  Colegios Publicos   Plaza Conde Suchil
# 4  Colegios Publicos             Malasaña
# 5  Colegios Publicos           Fuencarral
# 6  Colegios Publicos  Colegio Arquitectos
# 7  Colegios Publicos            Hortaleza
# 8  Colegios Publicos      Alonso Martínez
# 9  Colegios Publicos  Plaza de San Miguel
#
#                                     address     Distancia
# 0                       Puerta del Sol nº 1  7.255807e+06
# 1                       Puerta del Sol nº 1  7.255800e+06
# 2                    Calle Miguel Moya nº 1  7.256472e+06
# 3  Plaza del Conde del Valle de Súchil nº 3  7.257597e+06
# 4               Calle Manuela Malasaña nº 5  7.257083e+06
# 5                   Calle Fuencarral nº 108  7.257039e+06
# 6                     Calle Hortaleza nº 63  7.256297e+06
# 7                     Calle Hortaleza nº 75  7.256358e+06
# 8             Plaza de Alonso Martínez nº 5  7.256470e+06
# 9                  Plaza de San Miguel nº 9  7.256213e+06

# %%
## Función que con un "title" te devuleva (return) el resultado de la columna "name" en base a la distancia
